# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# #217. Contains Duplicate
#
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.

# %%
class Solution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        return len(set(nums)) != len(nums)

# %%
solver = Solution

nums = [1,2,3,1]
print(f"nums: {nums}, Output: {solver.containsDuplicate(solver, nums)}")

nums = [1,2,3,4]
print(f"nums: {nums}, Output: {solver.containsDuplicate(solver, nums)}")

nums = [1,1,1,3,3,4,3,2,4,2]
print(f"nums: {nums}, Output: {solver.containsDuplicate(solver, nums)}")
# Out:
# nums: [1, 2, 3, 1], Output: True
# nums: [1, 2, 3, 4], Output: False
# nums: [1, 1, 1, 3, 3, 4, 3, 2, 4, 2], Output: True

# %% [markdown]
# ![image.png](attachment:image.png)
