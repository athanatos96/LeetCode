# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %% [markdown]
# # 125. Valid Palindrome
#
# A phrase is a palindrome if, after converting all uppercase letters into lowercase letters and removing all non-alphanumeric characters, it reads the same forward and backward. Alphanumeric characters include letters and numbers.
#
# Given a string s, return true if it is a palindrome, or false otherwise.

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        s = s.lower()

        new_s = ''
        for i in s:
            if i.isalnum():
                new_s += i
        print(new_s)
        r_pointer = len(new_s) - 1
        l_pointer = 0

        while l_pointer < r_pointer:
            if new_s[l_pointer] != new_s[r_pointer]:
                return False
            l_pointer+=1
            r_pointer-=1
        
        return True

# %%
solver = Solution

s = "A man, a plan, a canal: Panama"
print(f"s: {s}, Output: {solver.isPalindrome(solver, s)}")

s = "race a car"
print(f"s: {s}, Output: {solver.isPalindrome(solver, s)}")

s = " "
print(f"s: {s}, Output: {solver.isPalindrome(solver, s)}")
# Out:
# amanaplanacanalpanama
# s: A man, a plan, a canal: Panama, Output: True
# raceacar
# s: race a car, Output: False
#
# s:  , Output: True

# %% [markdown]
# ![image.png](attachment:image.png)
