# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 88. Merge Sorted Array
#
# You are given two integer arrays nums1 and nums2, sorted in non-decreasing order, and two integers m and n, representing the number of elements in nums1 and nums2 respectively.
#
# Merge nums1 and nums2 into a single array sorted in non-decreasing order.
#
# The final sorted array should not be returned by the function, but instead be stored inside the array nums1. To accommodate this, nums1 has a length of m + n, where the first m elements denote the elements that should be merged, and the last n elements are set to 0 and should be ignored. nums2 has a length of n.

# %%
class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        """
        Do not return anything, modify nums1 in-place instead.
        """
        nums1_copy = nums1.copy()

        count_m = 0
        count_n = 0
        while count_m < m or count_n < n:
            
            nums1_val = nums1_copy[count_m] if count_m < m else 10**9 + 1 
            nums2_val = nums2[count_n] if count_n < n else 10**9 + 1

            if nums1_val < nums2_val:
                nums1[count_m + count_n] = nums1_val
                count_m += 1
            else:
                nums1[count_m + count_n] = nums2_val
                count_n += 1

# %%
solver = Solution

nums1 = [1,2,3,0,0,0]
m = 3
nums2 = [2,5,6]
n = 3
print(f"nums1: {nums1}, m: {m}, nums2:´{nums2}, n: {n}, ", end ="")
solver.merge(solver, nums1, m, nums2, n) 
print(f"Output: {nums1}")

nums1 = [1]
m = 1
nums2 = []
n = 0
print(f"nums1: {nums1}, m: {m}, nums2:´{nums2}, n: {n}, ", end ="")
solver.merge(solver, nums1, m, nums2, n) 
print(f"Output: {nums1}")

nums1 = [0]
m = 0
nums2 = [1]
n = 1
print(f"nums1: {nums1}, m: {m}, nums2:´{nums2}, n: {n}, ", end ="")
solver.merge(solver, nums1, m, nums2, n) 
print(f"Output: {nums1}")
# Out:
# nums1: [1, 2, 3, 0, 0, 0], m: 3, nums2:´[2, 5, 6], n: 3, Output: [1, 2, 2, 3, 5, 6]
# nums1: [1], m: 1, nums2:´[], n: 0, Output: [1]
# nums1: [0], m: 0, nums2:´[1], n: 1, Output: [1]

# %% [markdown]
# ![image.png](attachment:image.png)
