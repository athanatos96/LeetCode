# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %% [markdown]
# # 387. First Unique Character in a String
#
# Given a string s, find the first non-repeating character in it and return its index. If it does not exist, return -1.

# %%
class Solution:
    def firstUniqChar(self, s: str) -> int:
        for i in range(len(s)):
            if s[i] not in s[:i] + s[i+1:]:
                return i
        return -1

# %%
solver = Solution

s = "leetcode"
print(f"s: {s}, Output: {solver.firstUniqChar(solver, s)}")

s = "loveleetcode"
print(f"s: {s}, Output: {solver.firstUniqChar(solver, s)}")

s = "aabb"
print(f"s: {s}, Output: {solver.firstUniqChar(solver, s)}")
# Out:
# s: leetcode, Output: 0
# s: loveleetcode, Output: 2
# s: aabb, Output: -1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
