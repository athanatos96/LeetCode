# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 268. Missing Number
# Given an array nums containing n distinct numbers in the range [0, n], return the only number in the range that is missing from the array.

# %%
class Solution:
    def missingNumber(self, nums: List[int]) -> int:
        n = len(nums)
        return ((n * (n+1)) // 2 ) - sum(nums)

# %%
solver = Solution

nums = [3,0,1]
print(f"nums: {nums}, Output: {solver.missingNumber(solver, nums)}")

nums = [0,1]
print(f"nums: {nums}, Output: {solver.missingNumber(solver, nums)}")

nums = [9,6,4,2,3,5,7,0,1]
print(f"nums: {nums}, Output: {solver.missingNumber(solver, nums)}")
# Out:
# nums: [3, 0, 1], Output: 2
# nums: [0, 1], Output: 2
# nums: [9, 6, 4, 2, 3, 5, 7, 0, 1], Output: 8

# %% [markdown]
# ![image.png](attachment:image.png)
