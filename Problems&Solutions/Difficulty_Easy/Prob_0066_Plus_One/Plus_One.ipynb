# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 66. Plus One
#
# You are given a large integer represented as an integer array digits, where each digits[i] is the ith digit of the integer. The digits are ordered from most significant to least significant in left-to-right order. The large integer does not contain any leading 0's.
#
# Increment the large integer by one and return the resulting array of digits.

# %%
class Solution:
    def plusOne(self, digits: List[int]) -> List[int]:
        def convert(list):
            res = int("".join(map(str, list))) 
            return res 
        
        result = convert(digits) + 1
        
        result1 = [ int(i) for i in str(result) ]
        return result1

# %%
solver = Solution

lists = [1,2,3]
print(f"lists: {lists}, Output: k: {solver.plusOne(solver, lists)}")


lists = [4,3,2,1]
print(f"lists: {lists}, Output: k: {solver.plusOne(solver, lists)}")


lists = [9]
print(f"lists: {lists}, Output: k: {solver.plusOne(solver, lists)}")
# Out:
# lists: [1, 2, 3], Output: k: [1, 2, 4]
# lists: [4, 3, 2, 1], Output: k: [4, 3, 2, 2]
# lists: [9], Output: k: [1, 0]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
