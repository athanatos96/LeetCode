# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 46. Permutations
#
# Given an array nums of distinct integers, return all the possible permutations. You can return the answer in any order.

# %%
import itertools
class Solution:
    def permute(self, nums: List[int]) -> List[List[int]]:
        return list(itertools.permutations(nums))

# %%
solver = Solution

nums = [1,2,3]
print(f"nums: {nums}, Output: {solver.permute(solver, nums)}")

nums = [0,1]
print(f"nums: {nums}, Output: {solver.permute(solver, nums)}")

nums = [1]
print(f"nums: {nums}, Output: {solver.permute(solver, nums)}")
# Out:
# nums: [1, 2, 3], Output: [(1, 3, 2), (1, 2, 3), (2, 1, 3), (3, 2, 1), (3, 1, 2), (2, 3, 1)]
# nums: [0, 1], Output: [(0, 1), (1, 0)]
# nums: [1], Output: [(1,)]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
