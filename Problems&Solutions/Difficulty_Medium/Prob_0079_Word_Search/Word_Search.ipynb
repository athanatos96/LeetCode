# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 79. Word Search
#
# Given an m x n grid of characters board and a string word, return true if word exists in the grid.
#
# The word can be constructed from letters of sequentially adjacent cells, where adjacent cells are horizontally or vertically neighboring. The same letter cell may not be used more than once.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
class Solution:
    def exist(self, board: List[List[str]], word: str) -> bool:

        def search(i, j, letter = 0):
            #print("")
            #print(f"REC. (i,j):({i},{j}), posWord:{letter}, Lenght:{len(word)}")
            
            #print(f"down:{down}, up:{up}, right:{right}, left:{left}")
            if i > down or i < up or j > right or j < left: 
                #print("OUT OF RANGE")
                return False
            if letter>=len(word): return True
            #print(f"Letter: {word[letter]}")


            #print(f"Letters: {board[i][j]} == {word[letter]}")
            if board[i][j] == word[letter]:
                #print(f"Match, pos: ({i}, {j})")
                if (i, j) not in path:
                    #print(f"Position not in path: ({i},{j}), {path}")
                    path.append((i,j)) # Save the path
                    
                    if search(i+1, j, letter+1): return True
                    
                    if search(i-1, j, letter+1): return True

                    if search(i, j+1, letter+1): return True
                    
                    if search(i, j-1, letter+1): return True

                    path.pop()
            #print("Return False")
            return False


        left = 0
        right = len(board[0])-1
        up = 0
        down = len(board)-1

        for i in range(len(board)):
            for j in range(len(board[0])):

                if board[i][j] == word[0]:
                    #print(f"Position[i][j]: [{i}][{j}], elem: {board[i][j]}")
                    # Start search
                    if len(word)==1: return True
                    path = []
                    if search(i, j): return True

        return False

# %%
solver = Solution

board = [["A","B","C","E"],["S","F","C","S"],["A","D","E","E"]]
word = "ABCCED"
print(f"board: {board}, word: {word}, Output: {solver.exist(solver, board, word)}")

board = [["A","B","C","E"],["S","F","C","S"],["A","D","E","E"]]
word = "SEE"
print(f"board: {board}, word: {word}, Output: {solver.exist(solver, board, word)}")

board = [["A","B","C","E"],["S","F","C","S"],["A","D","E","E"]]
word = "ABCB"
print(f"board: {board}, word: {word}, Output: {solver.exist(solver, board, word)}")
# Out:
# board: [['A', 'B', 'C', 'E'], ['S', 'F', 'C', 'S'], ['A', 'D', 'E', 'E']], word: ABCCED, Output: True
# board: [['A', 'B', 'C', 'E'], ['S', 'F', 'C', 'S'], ['A', 'D', 'E', 'E']], word: SEE, Output: True
# board: [['A', 'B', 'C', 'E'], ['S', 'F', 'C', 'S'], ['A', 'D', 'E', 'E']], word: ABCB, Output: False

# %% [markdown]
# ![image-5.png](attachment:image-5.png)
