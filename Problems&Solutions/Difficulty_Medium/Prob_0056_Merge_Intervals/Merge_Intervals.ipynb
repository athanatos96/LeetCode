# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 56. Merge Intervals
#
# Given an array of intervals where intervals[i] = [starti, endi], merge all overlapping intervals, and return an array of the non-overlapping intervals that cover all the intervals in the input.

# %%
class Solution:
    def merge(self, intervals: List[List[int]]) -> List[List[int]]:
        
        intervals.sort(key= lambda x: x[0]) 

        i = 1
        while True:
            if i == len(intervals): break
            
            prev = intervals[i-1]
            current = intervals[i]

            if prev[1] >= current[0]:
                min(prev[0],current[0])
                intervals = intervals[:i-1] + [[min(prev[0],current[0]),max(prev[1],current[1])]] + intervals[i+1:]
            else:
                i+=1

        return intervals

# %%
solver = Solution

intervals = [[1,3],[2,6],[8,10],[15,18]]
print(f"intervals: {intervals}, Output: {solver.merge(solver, intervals)}")

intervals = [[1,4],[4,5]]
print(f"intervals: {intervals}, Output: {solver.merge(solver, intervals)}")
# Out:
# intervals: [[1, 3], [2, 6], [8, 10], [15, 18]], Output: [[1, 6], [8, 10], [15, 18]]
# intervals: [[1, 4], [4, 5]], Output: [[1, 5]]

# %% [markdown]
# ![image.png](attachment:image.png)
