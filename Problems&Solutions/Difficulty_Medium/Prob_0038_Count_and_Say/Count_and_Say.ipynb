# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 38. Count and Say
#
# The count-and-say sequence is a sequence of digit strings defined by the recursive formula:
#
# countAndSay(1) = "1"
# countAndSay(n) is the way you would "say" the digit string from countAndSay(n-1), which is then converted into a different digit string.
# To determine how you "say" a digit string, split it into the minimal number of substrings such that each substring contains exactly one unique digit. Then for each substring, say the number of digits, then say the digit. Finally, concatenate every said digit.
#
# For example, the saying and conversion for digit string "3322251":
# ![image.png](attachment:image.png)
# Given a positive integer n, return the nth term of the count-and-say sequence.

# %%
class Solution:
    def countAndSay(self, n: int) -> str:
        def say(number):
            str_sol = ""
            count = 0
            current = number[0]
            for i in number:
                if i == current:
                    count += 1
                else:
                    str_sol = str_sol + str(count) + current
                    count = 1
                    current = i
            
            str_sol = str_sol + str(count) + current
            return str_sol
        
        solution = "1"
        for i in range(2, n+1):
            solution = say(solution)
        return solution

# %%
solver = Solution

n = 1
print(f"n: {n}, Output: {solver.countAndSay(solver, n)}")

n = 4
print(f"n: {n}, Output: {solver.countAndSay(solver, n)}")

n = 8
print(f"n: {n}, Output: {solver.countAndSay(solver, n)}")
# Out:
# n: 1, Output: 1
# n: 4, Output: 1211
# n: 8, Output: 1113213211

# %% [markdown]
# ![image.png](attachment:image.png)
