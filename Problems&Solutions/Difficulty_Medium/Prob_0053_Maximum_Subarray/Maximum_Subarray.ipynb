# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 53. Maximum Subarray
#
# Given an integer array nums, find the subarray with the largest sum, and return its sum.

# %%
class Solution:
    def maxSubArray(self, nums: List[int]) -> int:
        max_val = -10**4
        current = -10**4
        for i in range(len(nums)):
            current = max(current+nums[i], nums[i])
            max_val = max(current, max_val)
        return max_val

# %%
solver = Solution

nums = [-2,1,-3,4,-1,2,1,-5,4]
print(f"nums: {nums}, Output: {solver.maxSubArray(solver, nums)}")

nums = [1]
print(f"nums: {nums}, Output: {solver.maxSubArray(solver, nums)}")

nums = [5,4,-1,7,8]
print(f"nums: {nums}, Output: {solver.maxSubArray(solver, nums)}")
# Out:
# nums: [-2, 1, -3, 4, -1, 2, 1, -5, 4], Output: 6
# nums: [1], Output: 1
# nums: [5, 4, -1, 7, 8], Output: 23

# %% [markdown]
# ![image.png](attachment:image.png)
