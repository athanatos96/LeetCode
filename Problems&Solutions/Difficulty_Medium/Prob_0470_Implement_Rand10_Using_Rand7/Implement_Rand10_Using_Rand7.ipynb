# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
import random

# %% [markdown]
# # 470. Implement Rand10() Using Rand7()
#
# Given the API rand7() that generates a uniform random integer in the range [1, 7], write a function rand10() that generates a uniform random integer in the range [1, 10]. You can only call the API rand7(), and you shouldn't call any other API. Please do not use a language's built-in random API.
#
# Each test case will have one internal argument n, the number of times that your implemented function rand10() will be called while testing. Note that this is not an argument passed to rand10().

# %%
# The rand7() API is already defined for you.
def rand7():
    return(random.randint(1, 7))
# @return a random integer in the range 1 to 7

class Solution:
    def rand10(self):
        """
        :rtype: int
        """
        def split():
            while True:
                r = rand7()
                if r < 4:
                    return 1
                elif r > 4:
                    return 2
        while True:
            s = split()
            r2 = rand7()
            if r2 < 6:
                break
        
        return r2 if s==1 else r2+5

# %%
solver = Solution

n = 1
print(f"n: {n}, Output: {[ solver.rand10(solver) for i in range(n)]}")

n = 2
print(f"n: {n}, Output: {[ solver.rand10(solver) for i in range(n)]}")

n = 3
print(f"n: {n}, Output: {[ solver.rand10(solver) for i in range(n)]}")

n = 100
print(f"n: {n}, Output: {[ solver.rand10(solver) for i in range(n)]}")
# Out:
# n: 1, Output: [8]
# n: 2, Output: [8, 6]
# n: 3, Output: [10, 1, 5]
# n: 100, Output: [8, 7, 10, 5, 10, 6, 8, 6, 7, 6, 10, 5, 5, 6, 6, 7, 2, 7, 1, 3, 7, 7, 8, 4, 8, 4, 3, 1, 1, 10, 4, 5, 5, 3, 10, 1, 10, 2, 2, 1, 2, 7, 10, 1, 2, 3, 2, 7, 9, 6, 3, 7, 1, 1, 7, 6, 10, 3, 8, 2, 2, 5, 1, 7, 6, 1, 10, 8, 4, 7, 3, 6, 5, 2, 10, 3, 1, 7, 1, 10, 6, 9, 5, 2, 6, 6, 9, 3, 8, 2, 7, 7, 8, 6, 4, 1, 4, 3, 3, 10]

# %% [markdown]
# ![image-4.png](attachment:image-4.png)
