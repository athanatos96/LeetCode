# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish
#
# **Ruslan Gokhman** https://github.com/Gokhman07

# %%
from typing import List

# %% [markdown]
# # 15. 3Sum
#
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0. Notice that the solution set must not contain duplicate triplets.

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        #Create an empty set and 3 empty lists for number filters
        res = set()
        n, p, z = [], [], []
        
        #Populate lists with positive numbers, negative numbers and zeros
        for num in nums:
            if num > 0:
                p.append(num)
            elif num < 0: 
                n.append(num)
            else:
                z.append(num)
                
        #Sort the negative numbers and the positives in ascending order        
        N, P = set(n), set(p)
        
        #Loop thrrough Zero list cases, create teh lists such that p=-n + 0
        if z:
            for num in P:
                if -1*num in N:
                    res.add((-1*num, 0, num))
        
        #Create the unique case of multiple 0
        if len(z) >= 3:
            res.add((0,0,0))
            
        #Loop though negative numbers and identify if their negative sum exists in the positive numbers. Add this
        #to the result tuple. 
        for i in range(len(n)):
            for j in range(i+1,len(n)):
                target = -1*(n[i] + n[j])
                if target in P:
                    res.add(tuple(sorted([n[i],n[j],target])))
                    
        #Repeat the process for positive list of numbers            
        for i in range(len(p)):
            for j in range(i+1,len(p)):
                target = -1*(p[i]+p[j])
                if target in N:
                    res.add(tuple(sorted([p[i],p[j],target])))
                    
        return res

# %%
solver = Solution

nums = [-1,0,1,2,-1,-4]
print(f"Nums: {nums}, is a Match: {solver.threeSum(solver, nums)}")

nums = [0,1,1]
print(f"Nums: {nums}, is a Match: {solver.threeSum(solver, nums)}")

nums = [0,0,0]
print(f"Nums: {nums}, is a Match: {solver.threeSum(solver, nums)}")

nums = [34,55,79,28,46,33,2,48,31,-3,84,71,52,-3,93,15,21,-43,57,-6,86,56,94,74,83,-14,28,-66,46,-49,62,-11,
        43,65,77,12,47,61,26,1,13,29,55,-82,76,26,15,-29,36,-29,10,-70,69,17,49]
print(f"Nums: {nums}, is a Match: {solver.threeSum(solver, nums)}")
# Out:
# Nums: [-1, 0, 1, 2, -1, -4], is a Match: {(-1, 0, 1), (-1, -1, 2)}
# Nums: [0, 1, 1], is a Match: set()
# Nums: [0, 0, 0], is a Match: {(0, 0, 0)}
# Nums: [34, 55, 79, 28, 46, 33, 2, 48, 31, -3, 84, 71, 52, -3, 93, 15, 21, -43, 57, -6, 86, 56, 94, 74, 83, -14, 28, -66, 46, -49, 62, -11, 43, 65, 77, 12, 47, 61, 26, 1, 13, 29, 55, -82, 76, 26, 15, -29, 36, -29, 10, -70, 69, 17, 49], is a Match: {(-14, 2, 12), (-49, 21, 28), (-70, 34, 36), (-49, -3, 52), (-82, 34, 48), (-70, -6, 76), (-29, 1, 28), (-82, 26, 56), (-43, 15, 28), (-29, -14, 43), (-70, -14, 84), (-82, 33, 49), (-66, 10, 56), (-70, 1, 69), (-82, 17, 65), (-66, 1, 65), (-66, 17, 49), (-43, -3, 46), (-49, -6, 55), (-49, 1, 48), (-49, 2, 47), (-70, 15, 55), (-43, 12, 31), (-14, -3, 17), (-11, -6, 17), (-70, 13, 57), (-11, 1, 10), (-82, 13, 69), (-49, 15, 34), (-82, 21, 61), (-82, 36, 46), (-3, 1, 2), (-82, -11, 93), (-43, -6, 49), (-43, 10, 33), (-70, 21, 49), (-66, -11, 77), (-49, 13, 36), (-29, 12, 17), (-43, 17, 26), (-43, -14, 57), (-66, -3, 69), (-14, 1, 13)}

# %% [markdown]
# ![image.png](attachment:image.png)
