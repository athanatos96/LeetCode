# %% [markdown]
# # Authors:
# **Alejandro C Parra** https://github.com/athanatos96
#
#
# **Atreish Ramlakhan** https://github.com/atreish

# %%
from typing import List

# %% [markdown]
# # 4. Median of Two Sorted Arrays
#
# Given two sorted arrays nums1 and nums2 of size m and n respectively, return the median of the two sorted arrays.
#
# The overall run time complexity should be O(log (m+n)).

# %%
class Solution:
    def findMedianSortedArrays(self, nums1: List[int], nums2: List[int]) -> float:
        m = len(nums1)
        n = len(nums2)

        merge = nums1 + nums2
        merge.sort()

        total = m + n

        half = total//2
        odd = total%2

        if odd:
            return merge[half]
        else:
            return (merge[half-1] + merge[half])/2

# %%
solver = Solution


nums1 = [1,3]
nums2 = [2]
print(f"For nums1 = {nums1} and nums2 = {nums2} results --> {solver.findMedianSortedArrays(solver, nums1, nums2)}")



nums1 = [1,2]
nums2 = [3,4]
print(f"For nums1 = {nums1} and nums2 = {nums2} results --> {solver.findMedianSortedArrays(solver, nums1, nums2)}")
# Out:
# For nums1 = [1, 3] and nums2 = [2] results --> 2
# For nums1 = [1, 2] and nums2 = [3, 4] results --> 2.5

# %% [markdown]
# ![image.png](attachment:image.png)
